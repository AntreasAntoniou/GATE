# %%
import torch
import numpy
import pandas as pd
import pathlib

# %%
source_csv_filepath = "/disk/scratch_fast1/aantoni2/GATE/23012024.csv"
source_csv_filepath = pathlib.Path(source_csv_filepath)

# %%
df = pd.read_csv(source_csv_filepath)
exp_names = df.iloc[:, 2].tolist()
dataset_names = df.iloc[:, 1].tolist()
metrics = df.columns[4:].tolist()

# print(metrics)

# %%
from collections import defaultdict


def get_non_empty_columns_and_values(df, index):
    non_empty_columns = df.loc[index].notnull()
    non_empty_columns = non_empty_columns[non_empty_columns == True]
    non_empty_columns = non_empty_columns.index.tolist()
    non_empty_values = df.loc[index, non_empty_columns].tolist()
    return dict(zip(non_empty_columns, non_empty_values))


df = pd.read_csv(source_csv_filepath)
exp_names = df.iloc[:, 2].tolist()
dataset_names = df.iloc[:, 1].tolist()
metrics = df.columns[4:].tolist()

dataset_to_metrics = defaultdict(set)

for idx, row in df.iterrows():
    dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())

print(dataset_to_metrics)

# dataset_names = {
#     "cityscapes",
#     "cifar100",
#     "fungi",
#     "omniglot",
#     "cubirds",
#     "aircraft",
#     "dtextures",
#     "vgg",
#     "mini",
#     "whale-dolphin",
#     "pokemonblipcaptions",
#     "medical",
#     "iwildcam",
#     "newyorkercaptioncontest",
#     "clevr",
#     "food101",
#     "diabetic",
#     "acdc",
#     "ucf",
#     "places365",
#     "kinetics",
#     "ade20k",
#     "flickr30k",
#     "chexpert",
#     "winoground",
#     "nyu",
#     "coco",
#     "ham10k",
#     "pascal",
#     "imagenet1k",
#     "hmdb51",
# }

dataset_name_to_target_metrics = {
    "imagenet1k": {
        "testing/ensemble_3/accuracy_top_5-epoch-mean",
        "testing/ensemble_3/loss-epoch-mean",
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "food101": {
        "testing/ensemble_3/accuracy_top_5-epoch-mean",
        "testing/ensemble_3/loss-epoch-mean",
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "cifar100": {
        "testing/ensemble_3/accuracy_top_5-epoch-mean",
        "testing/ensemble_3/loss-epoch-mean",
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "places365": {
        "testing/ensemble_3/accuracy_top_5-epoch-mean",
        "testing/ensemble_3/loss-epoch-mean",
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "happy": {
        "testing/ensemble_3/accuracy_top_5_individual-epoch-mean",
        "testing/ensemble_3/accuracy_top_1_individual-epoch-mean",
        "testing/ensemble_3/accuracy_top_1_species-epoch-mean",
        "testing/ensemble_3/accuracy_top_5_species-epoch-mean",
    },
    "fungi": {
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "aircraft": {
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "omniglot": {
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "cubirds": {
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "dtextures": {
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "vgg": {
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "mini": {
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
    },
    "diabetic": {
        "testing/ensemble_3/auc-macro",
    },
    "ham10k": {
        "testing/ensemble_3/auc-macro",
    },
    "chexpert": {
        "testing/ensemble_3/auc-macro",
    },
    "ade20k": {
        "testing/ensemble_3/mIoU",
        "testing/ensemble_3/dice_loss-epoch-mean",
    },
    "cityscapes": {
        "testing/ensemble_3/mIoU",
        "testing/ensemble_3/dice_loss-epoch-mean",
    },
    "coco-10k": {
        "testing/ensemble_3/mIoU",
        "testing/ensemble_3/dice_loss-epoch-mean",
    },
    "coco-164k": {
        "testing/ensemble_3/mIoU",
        "testing/ensemble_3/dice_loss-epoch-mean",
    },
    "pascal": {
        "testing/ensemble_3/mIoU",
        "testing/ensemble_3/dice_loss-epoch-mean",
    },
    "nyu": {
        "testing/ensemble_3/mIoU",
        "testing/ensemble_3/dice_loss-epoch-mean",
    },
    "winoground": {
        "testing/ensemble_3/text_to_image_accuracy_top_1-epoch-mean",
        "testing/ensemble_3/image_to_text_accuracy_top_1-epoch-mean",
    },
    "flickr30k": {
        "testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean",
        "testing/ensemble_3/text_to_image_accuracy_top_1-epoch-mean",
        "testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean",
        "testing/ensemble_3/image_to_text_accuracy_top_1-epoch-mean",
    },
    "newyorkercaptioncontest": {
        "testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean",
        "testing/ensemble_3/text_to_image_accuracy_top_1-epoch-mean",
        "testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean",
        "testing/ensemble_3/image_to_text_accuracy_top_1-epoch-mean",
    },
    "pokemonblipcaptions": {
        "testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean",
        "testing/ensemble_3/text_to_image_accuracy_top_1-epoch-mean",
        "testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean",
        "testing/ensemble_3/image_to_text_accuracy_top_1-epoch-mean",
    },
    "hmdb51": {
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
        "testing/ensemble_3/accuracy_top_5-epoch-mean",
    },
    "kinetics": {
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
        "testing/ensemble_3/accuracy_top_5-epoch-mean",
    },
    "ucf": {
        "testing/ensemble_3/accuracy_top_1-epoch-mean",
        "testing/ensemble_3/accuracy_top_5-epoch-mean",
    },
    "iwildcam": {"testing/ensemble_3/mae_loss-epoch-mean"},
    "clevr": {
        "testing/ensemble_5/accuracy_top_1-epoch-mean",
        "testing/ensemble_5/accuracy_top_5-epoch-mean",
    },
    "clevr-math": {
        "testing/ensemble_5/accuracy_top_1-epoch-mean",
        "testing/ensemble_5/accuracy_top_5-epoch-mean",
    },
    "acdc": {"testing/ensemble_3-/dice_loss-epoch-mean"},
    "medical": {"testing/ensemble_3-/dice_loss-epoch-mean"},
}
# Out:
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# /tmp/ipykernel_3383036/806640000.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset_to_metrics[row[1]].update(get_non_empty_columns_and_values(df, idx).keys())
# ...
#         'testing/ensemble_3/accuracy_top_5-epoch-mean',
#         'testing/ensemble_5/accuracy_top_5-epoch-std',
#         'testing/ensemble_3/loss-epoch-std',
#         'testing/ensemble_5/accuracy_top_1-epoch-mean',
#         'testing/ensemble_3/loss-epoch-mean',
#         'testing/ensemble_3/accuracy_top_5-epoch-std',
#         'testing/ensemble_5/loss-epoch-std',
#         'testing/ensemble_5/accuracy_top_5-epoch-mean',
#         'testing/ensemble_1/loss-epoch-std',
#         'testing/ensemble_1/accuracy_top_1-epoch-std'
#     },
#     'mini': {
#         'testing/ensemble_3/loss-epoch-mean',
#         'testing/ensemble_3/loss-epoch-std',
#         'testing/ensemble_5/accuracy_top_1-epoch-mean',
#         'Experiment-name',
#         'count',
#         'testing/ensemble_3/accuracy_top_1-epoch-mean',
#         'testing/ensemble_1/loss-epoch-mean',
#         'Experiment-series',
#         'testing/ensemble_5/accuracy_top_1-epoch-std',
#         'testing/ensemble_1/accuracy_top_1-epoch-mean',
#         'testing/ensemble_5/loss-epoch-std',
#         'testing/ensemble_1/loss-epoch-std',
#         'Dataset-name',
#         'testing/ensemble_1/accuracy_top_1-epoch-std',
#         'testing/ensemble_5/loss-epoch-mean',
#         'testing/ensemble_3/accuracy_top_1-epoch-std'
#     },
#     'omniglot': {
#         'testing/ensemble_3/loss-epoch-mean',
#         'testing/ensemble_3/loss-epoch-std',
#         'testing/ensemble_5/accuracy_top_1-epoch-mean',
#         'Experiment-name',
#         'count',
#         'testing/ensemble_3/accuracy_top_1-epoch-mean',
#         'testing/ensemble_1/loss-epoch-mean',
#         'Experiment-series',
#         'testing/ensemble_5/accuracy_top_1-epoch-std',
#         'testing/ensemble_1/accuracy_top_1-epoch-mean',
#         'testing/ensemble_5/loss-epoch-std',
#         'testing/ensemble_1/loss-epoch-std',
#         'Dataset-name',
#         'testing/ensemble_1/accuracy_top_1-epoch-std',
#         'testing/ensemble_5/loss-epoch-mean',
#         'testing/ensemble_3/accuracy_top_1-epoch-std'
#     },
#     'vgg': {
#         'testing/ensemble_3/loss-epoch-mean',
#         'testing/ensemble_3/loss-epoch-std',
#         'testing/ensemble_5/accuracy_top_1-epoch-mean',
#         'Experiment-name',
#         'count',
#         'testing/ensemble_3/accuracy_top_1-epoch-mean',
#         'testing/ensemble_1/loss-epoch-mean',
#         'Experiment-series',
#         'testing/ensemble_5/accuracy_top_1-epoch-std',
#         'testing/ensemble_1/accuracy_top_1-epoch-mean',
#         'testing/ensemble_5/loss-epoch-std',
#         'testing/ensemble_1/loss-epoch-std',
#         'Dataset-name',
#         'testing/ensemble_1/accuracy_top_1-epoch-std',
#         'testing/ensemble_5/loss-epoch-mean',
#         'testing/ensemble_3/accuracy_top_1-epoch-std'
#     },
#     'chexpert': {
#         'testing/ensemble_1/2-aps',
#         'testing/ensemble_1/2-bs',
#         'testing/ensemble_5/auc-macro',
#         'testing/ensemble_5/0-auc',
#         'testing/ensemble_5/aps-macro',
#         'Experiment-series',
#         'testing/ensemble_5/4-bs',
#         'testing/ensemble_3/2-bs',
#         'testing/ensemble_3/global_step',
#         'testing/ensemble_1/1-aps',
#         'testing/ensemble_3/1-aps',
#         'testing/ensemble_1/0-aps',
#         'testing/ensemble_3/0-aps',
#         'Dataset-name',
#         'testing/ensemble_3/0-auc',
#         'testing/ensemble_1/3-bs',
#         'testing/ensemble_3/3-aps',
#         'testing/ensemble_1/4-bs',
#         'testing/ensemble_1/ensemble_1-global_step',
#         'testing/ensemble_3/4-bs',
#         'testing/ensemble_5/0-aps',
#         'testing/ensemble_3/2-auc',
#         'Experiment-name',
#         'count',
#         'testing/ensemble_1/loss',
#         'testing/ensemble_1/0-bs',
#         'testing/ensemble_1/auc-macro',
#         'testing/ensemble_5/1-bs',
#         'testing/ensemble_5/global_step',
#         'testing/ensemble_3/2-aps',
#         'testing/ensemble_5/2-aps',
#         'testing/ensemble_5/1-auc',
#         'testing/ensemble_3/aps-macro',
#         'testing/ensemble_3/auc-macro',
#         'testing/ensemble_1/4-aps',
#         'testing/ensemble_5/3-aps',
#         'testing/ensemble_3/ensemble_3-global_step',
#         'testing/ensemble_3/1-auc',
#         'testing/ensemble_5/ensemble_5-global_step',
#         'testing/ensemble_3/3-bs',
#         'testing/ensemble_5/3-auc',
#         'testing/ensemble_5/loss',
#         'testing/ensemble_1/aps-macro',
#         'testing/ensemble_1/0-auc',
#         'testing/ensemble_5/2-bs',
#         'testing/ensemble_1/3-auc',
#         'testing/ensemble_1/4-auc',
#         'testing/ensemble_3/bs-macro',
#         'testing/ensemble_5/4-auc',
#         'testing/ensemble_3/loss',
#         'testing/ensemble_5/0-bs',
#         'testing/ensemble_1/bs-macro',
#         'testing/ensemble_3/4-auc',
#         'testing/ensemble_5/bs-macro',
#         'testing/ensemble_5/3-bs',
#         'testing/ensemble_1/global_step',
#         'testing/ensemble_1/3-aps',
#         'testing/ensemble_1/2-auc',
#         'testing/ensemble_1/1-auc',
#         'testing/ensemble_1/1-bs',
#         'testing/ensemble_3/1-bs',
#         'testing/ensemble_3/3-auc',
#         'testing/ensemble_5/2-auc',
#         'testing/ensemble_3/0-bs',
#         'testing/ensemble_5/1-aps',
#         'testing/ensemble_5/4-aps',
#         'testing/ensemble_3/4-aps'
#     },
#     'kinetics': {
#         'testing/ensemble_3/accuracy_top_1-epoch-mean',
#         'testing/ensemble_1/loss-epoch-mean',
#         'Experiment-series',
#         'testing/ensemble_1/accuracy_top_5-epoch-mean',
#         'Dataset-name',
#         'testing/ensemble_5/loss-epoch-mean',
#         'testing/ensemble_3/accuracy_top_1-epoch-std',
#         'Experiment-name',
#         'count',
#         'testing/ensemble_5/accuracy_top_1-epoch-std',
#         'testing/ensemble_1/accuracy_top_1-epoch-mean',
#         'testing/ensemble_1/accuracy_top_5-epoch-std',
#         'testing/ensemble_3/accuracy_top_5-epoch-mean',
#         'testing/ensemble_5/accuracy_top_5-epoch-std',
#         'testing/ensemble_3/loss-epoch-std',
#         'testing/ensemble_5/accuracy_top_1-epoch-mean',
#         'testing/ensemble_3/loss-epoch-mean',
#         'testing/ensemble_3/accuracy_top_5-epoch-std',
#         'testing/ensemble_5/loss-epoch-std',
#         'testing/ensemble_5/accuracy_top_5-epoch-mean',
#         'testing/ensemble_1/loss-epoch-std',
#         'testing/ensemble_1/accuracy_top_1-epoch-std'
#     },
#     'iwildcam': {
#         'testing/ensemble_5/mae_loss-epoch-std',
#         'testing/ensemble_5/mse_loss-epoch-std',
#         'testing/ensemble_1/loss-epoch-mean',
#         'Experiment-series',
#         'testing/ensemble_1/mae_loss-epoch-std',
#         'testing/ensemble_5/mae_loss-epoch-mean',
#         'Dataset-name',
#         'testing/ensemble_5/loss-epoch-mean',
#         'testing/ensemble_1/mse_loss-epoch-mean',
#         'Experiment-name',
#         'count',
#         'testing/ensemble_3/mse_loss-epoch-mean',
#         'testing/ensemble_3/loss-epoch-std',
#         'testing/ensemble_3/mae_loss-epoch-mean',
#         'testing/ensemble_5/mse_loss-epoch-mean',
#         'testing/ensemble_3/loss-epoch-mean',
#         'testing/ensemble_1/mse_loss-epoch-std',
#         'testing/ensemble_3/mse_loss-epoch-std',
#         'testing/ensemble_3/mae_loss-epoch-std',
#         'testing/ensemble_5/loss-epoch-std',
#         'testing/ensemble_1/loss-epoch-std',
#         'testing/ensemble_1/mae_loss-epoch-mean'
#     },
#     'acdc': {
#         'testing/ensemble_3/background_dice_loss-epoch-mean',
#         'testing/ensemble_5/mean_accuracy',
#         'testing/ensemble_5-/background_ce_loss-epoch-std',
#         'testing/ensemble_1/background_ce_loss-epoch-mean',
#         'testing/ensemble_3/background_focal_loss-epoch-mean',
#         'testing/ensemble_3/dice_loss-epoch-std',
#         'Experiment-series',
#         'testing/ensemble_3/background_focal_loss-epoch-std',
#         'testing/ensemble_3-/background_dice_loss-epoch-mean',
#         'testing/ensemble_1-/background_dice_loss-epoch-mean',
#         'testing/ensemble_5-/background_loss-epoch-std',
#         'testing/ensemble_3/background_ce_loss-epoch-std',
#         'testing/ensemble_3/background_ce_loss-epoch-mean',
#         'testing/ensemble_5/mIoU_complete',
#         'testing/ensemble_5/background_ce_loss-epoch-std',
#         'testing/ensemble_5-/background_dice_loss-epoch-mean',
#         'testing/ensemble_3-/dice_loss-epoch-std',
#         'testing/ensemble_5/background_focal_loss-epoch-std',
#         'testing/ensemble_5/mIoU',
#         'testing/ensemble_1-/background_focal_loss-epoch-mean',
#         'testing/ensemble_1-/background_ce_loss-epoch-mean',
#         'testing/ensemble_5/mean_accuracy_complete',
#         'testing/ensemble_1/dice_loss-epoch-mean',
#         'testing/ensemble_3-/background_ce_loss-epoch-std',
#         'testing/ensemble_1-/background_loss-epoch-mean',
#         'testing/ensemble_3/dice_loss-epoch-mean',
#         'testing/ensemble_1/mean_accuracy',
#         'testing/ensemble_1/dice_loss-epoch-std',
#         'Dataset-name',
#         'testing/ensemble_3/mean_accuracy_complete',
#         'testing/ensemble_5/background_ce_loss-epoch-mean',
#         'testing/ensemble_1/mean_accuracy_complete',
#         'testing/ensemble_3/background_dice_loss-epoch-std',
#         'testing/ensemble_5/background_dice_loss-epoch-mean',
#         'testing/ensemble_5-/background_loss-epoch-mean',
#         'testing/ensemble_1/background_dice_loss-epoch-mean',
#         'testing/ensemble_3/background_loss-epoch-mean',
#         'testing/ensemble_5/background_dice_loss-epoch-std',
#         'testing/ensemble_1/background_dice_loss-epoch-std',
#         'testing/ensemble_3-/background_loss-epoch-mean',
#         'testing/ensemble_3/overall_accuracy_complete',
#         'testing/ensemble_5/overall_accuracy_complete',
#         'testing/ensemble_5-/background_focal_loss-epoch-mean',
#         'testing/ensemble_3-/dice_loss-epoch-mean',
#         'testing/ensemble_1-/background_loss-epoch-std',
#         'count',
#         'testing/ensemble_5-/dice_loss-epoch-mean',
#         'testing/ensemble_1/mIoU_complete',
#         'testing/ensemble_1-/dice_loss-epoch-mean',
#         'testing/ensemble_5/overall_accuracy',
#         'testing/ensemble_5/background_loss-epoch-mean',
#         'testing/ensemble_5-/background_ce_loss-epoch-mean',
#         'testing/ensemble_3-/background_loss-epoch-std',
#         'testing/ensemble_1-/background_ce_loss-epoch-std',
#         'testing/ensemble_3-/background_focal_loss-epoch-std',
#         'testing/ensemble_1/background_focal_loss-epoch-mean',
#         'testing/ensemble_5/background_focal_loss-epoch-mean',
#         'testing/ensemble_1/background_ce_loss-epoch-std',
#         'testing/ensemble_3/overall_accuracy',
#         'testing/ensemble_1/overall_accuracy',
#         'testing/ensemble_5-/background_dice_loss-epoch-std',
#         'testing/ensemble_1-/background_dice_loss-epoch-std',
#         'Experiment-name',
#         'testing/ensemble_5-/background_focal_loss-epoch-std',
#         'testing/ensemble_3/background_loss-epoch-std',
#         'testing/ensemble_1/overall_accuracy_complete',
#         'testing/ensemble_1/background_loss-epoch-mean',
#         'testing/ensemble_1/background_focal_loss-epoch-std',
#         'testing/ensemble_1-/background_focal_loss-epoch-std',
#         'testing/ensemble_5-/dice_loss-epoch-std',
#         'testing/ensemble_5/dice_loss-epoch-std',
#         'testing/ensemble_5/background_loss-epoch-std',
#         'testing/ensemble_3/mIoU',
#         'testing/ensemble_3-/background_dice_loss-epoch-std',
#         'testing/ensemble_3-/background_focal_loss-epoch-mean',
#         'testing/ensemble_3-/background_ce_loss-epoch-mean',
#         'testing/ensemble_1-/dice_loss-epoch-std',
#         'testing/ensemble_1/mIoU',
#         'testing/ensemble_3/mean_accuracy',
#         'testing/ensemble_5/dice_loss-epoch-mean',
#         'testing/ensemble_3/mIoU_complete',
#         'testing/ensemble_1/background_loss-epoch-std'
#     },
#     'medical': {
#         'testing/ensemble_3/background_dice_loss-epoch-mean',
#         'testing/ensemble_5/mean_accuracy',
#         'testing/ensemble_5-/background_ce_loss-epoch-std',
#         'testing/ensemble_1/background_ce_loss-epoch-mean',
#         'testing/ensemble_3/dice_loss-epoch-std',
#         'Experiment-series',
#         'testing/ensemble_3-/background_dice_loss-epoch-mean',
#         'testing/ensemble_1-/background_dice_loss-epoch-mean',
#         'testing/ensemble_5-/background_loss-epoch-std',
#         'testing/ensemble_5-/loss-epoch-std',
#         'testing/ensemble_3/background_ce_loss-epoch-std',
#         'testing/ensemble_3/background_ce_loss-epoch-mean',
#         'testing/ensemble_5/mIoU_complete',
#         'testing/ensemble_5/background_ce_loss-epoch-std',
#         'testing/ensemble_5-/background_dice_loss-epoch-mean',
#         'testing/ensemble_3-/dice_loss-epoch-std',
#         'testing/ensemble_5/mIoU',
#         'testing/ensemble_1-/background_ce_loss-epoch-mean',
#         'testing/ensemble_5/mean_accuracy_complete',
#         'testing/ensemble_1/dice_loss-epoch-mean',
#         'testing/ensemble_3-/background_ce_loss-epoch-std',
#         'testing/ensemble_1-/background_loss-epoch-mean',
#         'testing/ensemble_5/loss-epoch-std',
#         'testing/ensemble_1/loss-epoch-std',
#         'testing/ensemble_3/dice_loss-epoch-mean',
#         'testing/ensemble_1/mean_accuracy',
#         'testing/ensemble_1/dice_loss-epoch-std',
#         'testing/ensemble_1-/loss-epoch-mean',
#         'testing/ensemble_1/loss-epoch-mean',
#         'Dataset-name',
#         'testing/ensemble_3/mean_accuracy_complete',
#         'testing/ensemble_5/background_ce_loss-epoch-mean',
#         'testing/ensemble_1/mean_accuracy_complete',
#         'testing/ensemble_3/background_dice_loss-epoch-std',
#         'testing/ensemble_5/background_dice_loss-epoch-mean',
#         'testing/ensemble_5-/background_loss-epoch-mean',
#         'testing/ensemble_1/background_dice_loss-epoch-mean',
#         'testing/ensemble_3/background_loss-epoch-mean',
#         'testing/ensemble_5/background_dice_loss-epoch-std',
#         'testing/ensemble_1/background_dice_loss-epoch-std',
#         'testing/ensemble_3-/background_loss-epoch-mean',
#         'testing/ensemble_3/overall_accuracy_complete',
#         'testing/ensemble_5/overall_accuracy_complete',
#         'testing/ensemble_3-/dice_loss-epoch-mean',
#         'testing/ensemble_5/loss-epoch-mean',
#         'testing/ensemble_1-/background_loss-epoch-std',
#         'count',
#         'testing/ensemble_5-/dice_loss-epoch-mean',
#         'testing/ensemble_3/loss-epoch-std',
#         'testing/ensemble_1/mIoU_complete',
#         'testing/ensemble_1-/dice_loss-epoch-mean',
#         'testing/ensemble_5/overall_accuracy',
#         'testing/ensemble_5/background_loss-epoch-mean',
#         'testing/ensemble_5-/background_ce_loss-epoch-mean',
#         'testing/ensemble_3-/background_loss-epoch-std',
#         'testing/ensemble_1-/background_ce_loss-epoch-std',
#         'testing/ensemble_3/loss-epoch-mean',
#         'testing/ensemble_5-/loss-epoch-mean',
#         'testing/ensemble_1/background_ce_loss-epoch-std',
#         'testing/ensemble_3/overall_accuracy',
#         'testing/ensemble_3-/loss-epoch-std',
#         'testing/ensemble_1/overall_accuracy',
#         'testing/ensemble_5-/background_dice_loss-epoch-std',
#         'testing/ensemble_1-/background_dice_loss-epoch-std',
#         'Experiment-name',
#         'testing/ensemble_3/background_loss-epoch-std',
#         'testing/ensemble_1/overall_accuracy_complete',
#         'testing/ensemble_1/background_loss-epoch-mean',
#         'testing/ensemble_5-/dice_loss-epoch-std',
#         'testing/ensemble_3-/loss-epoch-mean',
#         'testing/ensemble_5/dice_loss-epoch-std',
#         'testing/ensemble_5/background_loss-epoch-std',
#         'testing/ensemble_3/mIoU',
#         'testing/ensemble_3-/background_dice_loss-epoch-std',
#         'testing/ensemble_3-/background_ce_loss-epoch-mean',
#         'testing/ensemble_1-/dice_loss-epoch-std',
#         'testing/ensemble_1/mIoU',
#         'testing/ensemble_3/mean_accuracy',
#         'testing/ensemble_5/dice_loss-epoch-mean',
#         'testing/ensemble_3/mIoU_complete',
#         'testing/ensemble_1-/loss-epoch-std',
#         'testing/ensemble_1/background_loss-epoch-std'
#     }
# })

# %%
model_to_dataset_to_metrics = defaultdict(dict)

def extract_model_name(exp_name: str, dataset_name: str) -> str:
    model_name = exp_name.replace(dataset_name, "")
    model_name = "-".join(model_name.split("-")[1:-1])
    model_name = model_name.replace("--", "").replace("classification-", "")
    model_name = model_name.replace("-fs-", "").replace("happy", "")
    model_name = model_name.replace("retionopathy", "")
    model_name = model_name[1:] if model_name[0] == "-" else model_name
    model_name = model_name[1:] if model_name[0] == "-" else model_name
    return model_name

for idx, row in df.iterrows():
    results_dict = get_non_empty_columns_and_values(df, idx)
    exp_name = results_dict["Experiment-name"]
    exp_dataset_name = results_dict["Dataset-name"]
    exp_dataset_name = (
        exp_dataset_name
        if exp_dataset_name!= "happy"
        else "whale-dolphin"
    )
    exp_dataset_name = (
        "clevr-math" if "clevr-math" in exp_name else "clevr"
        if exp_dataset_name == "clevr"
        else exp_dataset_name
    )
    exp_dataset_name = (
        "coco-10k" if "coco-10k" in exp_name else "coco-164k"
        if exp_dataset_name == "coco"
        else exp_dataset_name
    )
    model_name = extract_model_name(exp_name=exp_name, dataset_name=exp_dataset_name)
    
    for metric in dataset_to_metrics[exp_dataset_name]:
        if metric in dataset_name_to_target_metrics[exp_dataset_name]:
            model_to_dataset_to_metrics[model_name][exp_dataset_name] = model_to_dataset_to_metrics[model_name].get(exp_dataset_name, dict())
            model_to_dataset_to_metrics[model_name][exp_dataset_name][metric] = results_dict.get(metric, None)

# %%
print(model_to_dataset_to_metrics)
# Out:
# defaultdict(<class 'dict'>, {
#     'Laion-B16-224': {
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 74.12284088134766,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 93.0426788330078,
#             'testing/ensemble_3/loss-epoch-mean': 1.0822848081588743
#         },
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9609519243240356},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': None},
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.8483467977698329},
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.9861824760412083},
#         'ade20k': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'cityscapes': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': None
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9077158570289612},
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 52.91320037841797,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 83.65859985351562,
#             'testing/ensemble_3/loss-epoch-mean': 1.8045473098754885
#         },
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9663684368133544},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.853569746017456},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9894301295280457},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.8212401176414821},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 52.62766647338867,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.2122193723917007,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.2129851579666137
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.8563878536224365,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.91015625
#         }
#     },
#     'RNX50-32x4A1': {
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 86.0768814086914,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 97.23892211914062,
#             'testing/ensemble_3/loss-epoch-mean': 0.5837532877922058
#         },
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 51.78196334838867,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 82.85409545898438,
#             'testing/ensemble_3/loss-epoch-mean': 1.8095495700836184
#         },
#         'diabetic': {'testing/ensemble_3/auc-macro': None},
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 77.59750366210938,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 93.34239196777344,
#             'testing/ensemble_3/loss-epoch-mean': 1.024538516998291
#         },
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.6594047546386719},
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.9789835350753876},
#         'ade20k': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1595414876937866,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.1651065498590469
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.557812511920929},
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 69.3371810913086,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 91.85907745361328,
#             'testing/ensemble_3/loss-epoch-mean': 1.1859039068222046
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9161628484725952},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.7406187653541565},
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9280182719230652},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9850223660469056},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.8114190982223916},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 40.969688415527344,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1655346304178238,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.1713708043098449
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.6022518277168274,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.6394761204719543
#         }
#     },
#     'Flex-B-1200EP': {
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8371456265449524},
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.8571491969213547},
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.95947265625},
#         'ham10k': {'testing/ensemble_3/auc-macro': None},
#         'ade20k': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'cityscapes': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2143191844224929,
#             'testing/ensemble_3/mIoU': 1.2113816104829311
#         },
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': None
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9164249897003174},
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 52.08406448364258,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 83.33570861816406,
#             'testing/ensemble_3/loss-epoch-mean': 1.7830153703689575
#         },
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.7837079763412476},
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9638612866401672},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9891414642333984},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.8320752690430522},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 51.6817626953125,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.7860753536224365,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.8017003536224365
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1992532461881637,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.1976645737886428
#         }
#     },
#     'AR-ViT-B16-224': {
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.8384652085271},
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 77.88922882080078,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 92.7429656982422,
#             'testing/ensemble_3/loss-epoch-mean': 1.2058323621749878
#         },
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9439882636070251},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.794082522392273},
#         'ham10k': {'testing/ensemble_3/auc-macro': None},
#         'ade20k': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'cityscapes': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1972031891345977,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.2066210061311721
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.935413420200348},
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 83.87751007080078,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 96.60601043701172,
#             'testing/ensemble_3/loss-epoch-mean': 0.5825947523117065
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9442311525344848},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.7744154930114746},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9855965971946716},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.8177127680408288},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 51.92095565795898,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.8017003536224365,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.8134191036224365
#         }
#     },
#     'SViT-B16-224': {
#         'diabetic': {'testing/ensemble_3/auc-macro': None},
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 75.4775390625,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 90.76885986328124,
#             'testing/ensemble_3/loss-epoch-mean': 2.27593207359314
#         },
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 50.29856872558594,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 80.05573272705078,
#             'testing/ensemble_3/loss-epoch-mean': 1.8771889209747312
#         },
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9340289235115052},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8189936876296997},
#         'ham10k': {'testing/ensemble_3/auc-macro': None},
#         'ade20k': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6820487380027771,
#             'testing/ensemble_3/mIoU': 18.177081644535065
#         },
#         'cityscapes': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': None
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1780964583158493,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.1834474802017212
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.8046875,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.786994457244873
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9387136697769164},
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 75.66199493408203,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 93.54476928710938,
#             'testing/ensemble_3/loss-epoch-mean': 0.9572091102600098
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.929111659526825},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.7768310308456421},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9856967329978944},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.8276696697833048},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 50.73372650146485,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         }
#     },
#     'DINO-B16-224': {
#         'diabetic': {'testing/ensemble_3/auc-macro': None},
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 66.6003189086914,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 89.73925018310547,
#             'testing/ensemble_3/loss-epoch-mean': 1.1894962787628174
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': None},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': None},
#         'ham10k': {'testing/ensemble_3/auc-macro': None},
#         'ade20k': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'cityscapes': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': None
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9124262928962708},
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 47.50601959228515,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 79.85442352294922,
#             'testing/ensemble_3/loss-epoch-mean': 1.9906035661697388
#         },
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9592891335487366},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8126122951507568},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9874560832977296},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.8213706219914452},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 52.4664421081543,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1999952495098114,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.1997479051351547
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.814338207244873,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.8563878536224365
#         }
#     },
#     'SIGLIP-P16-224': {
#         'diabetic': {'testing/ensemble_3/auc-macro': None},
#         'ade20k': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.7807887196540833,
#             'testing/ensemble_3/mIoU': 30.40088713169098
#         },
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9744029641151428},
#         'cityscapes': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.1918725222349167,
#             'testing/ensemble_3/mIoU': 3.959287330508232
#         },
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.2097745388746261,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.2092227935791015
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.2201055735349655,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.2175370901823044
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': None},
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 76.83120727539062,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 94.7253189086914,
#             'testing/ensemble_3/loss-epoch-mean': 0.8092064261436462
#         },
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 93.3039321899414,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 99.10997009277344,
#             'testing/ensemble_3/loss-epoch-mean': 0.2418812811374664
#         },
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 54.14678192138672,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 84.55615234375,
#             'testing/ensemble_3/loss-epoch-mean': 1.7018355131149292
#         },
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9688279032707214},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8858095407485962},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.857012152671814},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.989737868309021},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.8227428291953869},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 52.72636795043945,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.8359375,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.859375
#         },
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.9865915005699638}
#     },
#     'EffV2-RW-S': {
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.8609970216846804},
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8931333422660828},
#         'ham10k': {'testing/ensemble_3/auc-macro': None},
#         'ade20k': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': None
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1698154509067535,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.1739726066589355
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.6297612190246582},
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 67.25716400146484,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 90.71456909179688,
#             'testing/ensemble_3/loss-epoch-mean': 1.2695910930633545
#         },
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 86.4012451171875,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 97.14794158935548,
#             'testing/ensemble_3/loss-epoch-mean': 0.561424970626831
#         },
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 51.49244689941406,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 82.56458282470703,
#             'testing/ensemble_3/loss-epoch-mean': 1.8307654857635496
#         },
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9207040667533876},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.6029778122901917},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.737069845199585},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9863043427467346},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.819186635471497},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 40.49549102783203,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.6208639740943909,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.6472886204719543
#         }
#     },
#     'DeiT3-B16-224': {
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.985951044343354},
#         'ade20k': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': None
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.202002465724945,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.2129185646772385
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9317757487297058},
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 87.29918670654297,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 97.74129486083984,
#             'testing/ensemble_3/loss-epoch-mean': 0.4433033168315887
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.953184187412262},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8187364935874939},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8059267401695251},
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': None},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9862625002861024},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.8285235859113979},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 52.34406280517578,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.8095128536224365,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.822150707244873
#         }
#     },
#     'depth-v2-Flex-B-1200EP': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2758360803127289,
#             'testing/ensemble_3/mIoU': 6.103634461760521
#         }
#     },
#     'depth-v2-EffV2-RW-S': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2427948266267776,
#             'testing/ensemble_3/mIoU': 8.314280211925507
#         }
#     },
#     'context-Laion-B16-224': {
#         'pascal': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None}
#     },
#     'ConvNextV2-Base': {
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0790049508213996,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0790049508213996
#         },
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9952229261398317,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 5.035828113555908,
#             'testing/ensemble_3/loss-epoch-mean': 4.607325553894043
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': None},
#         'diabetic': {'testing/ensemble_3/auc-macro': None},
#         'ham10k': {'testing/ensemble_3/auc-macro': None},
#         'ade20k': {'testing/ensemble_3/dice_loss-epoch-mean': None, 'testing/ensemble_3/mIoU': None},
#         'cityscapes': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.1988094449043274,
#             'testing/ensemble_3/mIoU': 2.906447649002075
#         },
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': None
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.8999183177947998},
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.0999040901660919,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 0.4995204508304596,
#             'testing/ensemble_3/loss-epoch-mean': 6.909462451934815
#         },
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.2736427187919616,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 1.3682136535644531,
#             'testing/ensemble_3/loss-epoch-mean': 5.901496410369873
#         },
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.6070466272393551},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 39.43299865722656,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1321231722831726,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.1321231722831726
#         }
#     },
#     'gulprgb-Flex-B-1200EP': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None
#         }
#     },
#     '101-gulprgb-AR-ViT-B16-224': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 66.5611801147461,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 85.45809936523438
#         }
#     },
#     '101-gulprgb-DINO-B16-224': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None
#         }
#     },
#     '101-gulprgb-DeiT3-B16-224': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None
#         }
#     },
#     'EffFormer-s0': {
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 25.230955123901367,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 55.16473388671875,
#             'testing/ensemble_3/loss-epoch-mean': 3.337228775024414
#         },
#         'ade20k': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.656323254108429,
#             'testing/ensemble_3/mIoU': 9.821125119924544
#         },
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1553177237510681,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.1512509435415268
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1577625572681427,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.1495386213064193
#         },
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.812653660774231},
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 15.605095863342283,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 42.33678436279297,
#             'testing/ensemble_3/loss-epoch-mean': 3.5262820720672607
#         },
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 60.87886047363281,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 86.2355728149414,
#             'testing/ensemble_3/loss-epoch-mean': 1.5647268295288086
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.7823545336723328},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.5847968459129333},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.4859080612659454},
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.862625002861023},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.956771731376648},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.7994214532072282},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 43.78937149047851,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.7821691036224365,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.786994457244873
#         }
#     },
#     'depth-v2-DeiT3-B16-224': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2762896418571472,
#             'testing/ensemble_3/mIoU': 7.602392882108688
#         }
#     },
#     'depth-v2-EffFormer-s0': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2356650680303573,
#             'testing/ensemble_3/mIoU': 10.549190640449524
#         }
#     },
#     'context-DINO-B16-224': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6857568025588989,
#             'testing/ensemble_3/mIoU': 17.404858767986298
#         }
#     },
#     'context-Flex-B-1200EP': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6858233213424683,
#             'testing/ensemble_3/mIoU': 21.07045352458954
#         }
#     },
#     'context-SIGLIP-P16-224': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.5975688099861145,
#             'testing/ensemble_3/mIoU': 35.69605052471161
#         }
#     },
#     'gulprgb-AR-ViT-B16-224': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 32.777442932128906,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 58.7740364074707
#         }
#     },
#     'gulprgb-SViT-B16-224': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 22.33072853088379,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 56.01963424682617
#         }
#     },
#     'gulprgb-SIGLIP-P16-224': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 39.90885543823242,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 70.5478744506836
#         }
#     },
#     'gulprgb-RNX50-32x4A1': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 5.611979007720947,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 23.0078125
#         }
#     },
#     '101-gulprgb-SViT-B16-224': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None
#         }
#     },
#     '101-gulprgb-Flex-B-1200EP': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None
#         }
#     },
#     'CLIP-B16-224': {
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 81.87140655517578,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 95.7420883178711,
#             'testing/ensemble_3/loss-epoch-mean': 0.7508324980735779
#         },
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 74.64171600341797,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 93.76990509033205,
#             'testing/ensemble_3/loss-epoch-mean': 0.9006643891334534
#         },
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 91.5673828125,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 98.70252990722656,
#             'testing/ensemble_3/loss-epoch-mean': 0.3014184236526489
#         },
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 53.38441467285156,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 83.82826232910156,
#             'testing/ensemble_3/loss-epoch-mean': 1.75825035572052
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9654890894889832},
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.979047954082489},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8428650498390198},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8558568358421326},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9887989163398744},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.8189968631688407},
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.8667237433225635},
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.986276339082928},
#         'ade20k': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6873555779457092,
#             'testing/ensemble_3/mIoU': 33.492591977119446
#         },
#         'cityscapes': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2150442153215408,
#             'testing/ensemble_3/mIoU': 1.099383644759655
#         },
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.2027111798524856,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.2102929949760437
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.2029585242271423,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.2086139619350433
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.8134191036224365,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.84765625
#         },
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 52.64596939086914,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         }
#     },
#     'imagenetCLIP-B16-224': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9623966217041016}},
#     'flowersCLIP-B16-224': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9888461232185364}},
#     'depth-v2-CLIP-B16-224': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.290254533290863,
#             'testing/ensemble_3/mIoU': 7.670620828866959
#         }
#     },
#     'context-CLIP-B16-224': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6304150223731995,
#             'testing/ensemble_3/mIoU': 25.35834014415741
#         }
#     },
#     '400-CLIP-B16-224': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 44.196659088134766,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 70.89091491699219
#         }
#     },
#     '2022-CLIP-B16-224': {'iwildcam': {'testing/ensemble_3/mae_loss-epoch-mean': 1.4078165292739868}},
#     '101-gulprgb-CLIP-B16-224': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 75.10548400878906,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 91.05635833740234
#         }
#     },
#     'gulprgb-CLIP-B16-224': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 40.6640625,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 70.0390625
#         }
#     },
#     'CLIP-B16-224HF-text': {
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9645933508872986},
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.561371922492981},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.3486238420009613},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.3727907538414001},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8925724029541016},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.6310346203418172},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 44.53766632080078,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0781154930591583,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0794330313801765
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.7028952240943909,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.7410386204719543
#         },
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0817874819040298,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0794330313801765
#         },
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.864255457653441},
#         'cityscapes': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2217081487178802,
#             'testing/ensemble_3/mIoU': 0.0
#         },
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.5660264712638826},
#         'ade20k': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6709109544754028,
#             'testing/ensemble_3/mIoU': 0.3714996622875333
#         },
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         }
#     },
#     'CLIP-B16-224HF-image': {
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9618260264396667},
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 29.80640411376953,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 57.36922836303711,
#             'testing/ensemble_3/loss-epoch-mean': 2.9532055854797363
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.4984288513660431},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.6747445135135848},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 44.6197395324707,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0907772108912468,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0961282327771186
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.7449448704719543,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.8095128536224365
#         },
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.087994672358036,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0944159030914306
#         },
#         'ade20k': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6716094613075256,
#             'testing/ensemble_3/mIoU': 0.36436109803617
#         },
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.9277575589394668},
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.5908818436263156},
#         'cityscapes': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2205114662647247,
#             'testing/ensemble_3/mIoU': 0.0
#         },
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         }
#     },
#     'BART': {
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9663102030754088},
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'cubirds': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.503052294254303},
#         'dtextures': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.3592873215675354},
#         'fungi': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.3365265727043152},
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.5330041646957397},
#         'omniglot': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8409921526908875},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.6395463925784222},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 42.35087966918945,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0778110697865486,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0794330313801765
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.6980698704719543,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.747931957244873
#         },
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.8527494505965668},
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.082339234650135,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0798611119389534
#         },
#         'cityscapes': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2168232798576355,
#             'testing/ensemble_3/mIoU': 0.0
#         },
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.5270939129202749},
#         'ade20k': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6680971384048462,
#             'testing/ensemble_3/mIoU': 0.3804929787293077
#         },
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 11.552959442138672,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 32.01694107055664,
#             'testing/ensemble_3/loss-epoch-mean': 3.884697675704956
#         },
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         }
#     },
#     'BERT': {
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9673150777816772},
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.5957820415496826},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.6658916387455033},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 42.47232437133789,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.5939190872094517},
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0793093591928482,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0795233994722366
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.7215073704719543,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.763556957244873
#         },
#         'cityscapes': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2179359495639801,
#             'testing/ensemble_3/mIoU': 0.0
#         },
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0816638097167015,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0805032327771186
#         },
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.8903190664345149},
#         'ade20k': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6696582436561584,
#             'testing/ensemble_3/mIoU': 0.3618240589275956
#         },
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 18.73789978027344,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 43.02122116088867,
#             'testing/ensemble_3/loss-epoch-mean': 3.486268281936645
#         },
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         }
#     },
#     'MPNET': {
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9619891047477722},
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9889240264892578,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 4.944620132446289,
#             'testing/ensemble_3/loss-epoch-mean': 4.615601539611816
#         },
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'aircraft': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.5719502568244934},
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.6397663177412527},
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.5402713611266806},
#         'clevr': {
#             'testing/ensemble_5/accuracy_top_1-epoch-mean': 41.10210418701172,
#             'testing/ensemble_5/accuracy_top_5-epoch-mean': None
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0785768628120422,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0785768628120422
#         },
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.1321231722831726,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.1321231722831726
#         },
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0785768628120422,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0785768628120422
#         },
#         'ade20k': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6698814034461975,
#             'testing/ensemble_3/mIoU': 0.3686649492010474
#         },
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.7933129564874964},
#         'cityscapes': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2190368473529815,
#             'testing/ensemble_3/mIoU': 0.0
#         },
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         }
#     },
#     'Whisper': {
#         'acdc': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.966912031173706},
#         'food101': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 15.074925422668455,
# ...
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.201122522354126,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.2004804015159607
#         },
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.8133277153289524}
#     },
#     'W2V2': {
#         'places365': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'chexpert': {'testing/ensemble_3/auc-macro': 0.6319666975562703},
#         'diabetic': {'testing/ensemble_3/auc-macro': 0.5360062808006681},
#         'pokemonblipcaptions': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.6638327240943909,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.6725643277168274
#         },
#         'newyorkercaptioncontest': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0785768628120422,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0807172730565071
#         },
#         'ade20k': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6687197089195251,
#             'testing/ensemble_3/mIoU': 0.3678996814414859
#         },
#         'cityscapes': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2144821882247924,
#             'testing/ensemble_3/mIoU': 0.0
#         },
#         'flickr30k': {
#             'testing/ensemble_3/image_to_text_accuracy_top_5-epoch-mean': 0.0785768628120422,
#             'testing/ensemble_3/text_to_image_accuracy_top_5-epoch-mean': 0.0785768628120422
#         },
#         'ham10k': {'testing/ensemble_3/auc-macro': 0.8408254091693956},
#         'cifar100': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         },
#         'imagenet1k': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': None,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': None,
#             'testing/ensemble_3/loss-epoch-mean': None
#         }
#     },
#     'imagenetBART': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.3729495108127594}},
#     'imagenetCLIP-B16-224HF-text': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.4575733542442322}},
#     'imagenetAR-ViT-B16-224': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9865550994873048}},
#     'imagenetLaion-B16-224': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.908463418483734}},
#     'imagenetSViT-B16-224': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9210808277130128}},
#     'imagenetDINO-B16-224': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8989405035972595}},
#     'imagenetFlex-B-1200EP': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9908115863800048}},
#     'imagenetSIGLIP-P16-224': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9167057275772096}},
#     'imagenetEffFormer-s0': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9092364311218262}},
#     'imagenetEffV2-RW-S': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.632358729839325}},
#     'context-DeiT3-B16-224': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6616457104682922,
#             'testing/ensemble_3/mIoU': 20.99478393793106
#         }
#     },
#     'context-EffV2-RW-S': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.6127204298973083,
#             'testing/ensemble_3/mIoU': 11.739031970500946
#         }
#     },
#     'context-ConvNextV2-Base': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.676672101020813,
#             'testing/ensemble_3/mIoU': 1.0831288993358612
#         }
#     },
#     'imagenetRNX50-32x4A1': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.7826793193817139}},
#     'flowersCLIP-B16-224HF-text': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.6693249344825745}},
#     'flowersAR-ViT-B16-224': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9530511498451232}},
#     'flowersLaion-B16-224': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.967875063419342}},
#     'flowersSViT-B16-224': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.934037148952484}},
#     'flowersDINO-B16-224': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9589460492134094}},
#     'flowersDeiT3-B16-224': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9616769552230836}},
#     'flowersFlex-B-1200EP': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9669435620307922}},
#     'flowersSIGLIP-P16-224': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.9850535988807678}},
#     'flowersEffFormer-s0': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.906310498714447}},
#     'flowersEffV2-RW-S': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.913297951221466}},
#     'flowersRNX50-32x4A1': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.8792724609375}},
#     'gulprgb-MPNET': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 1.953125,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 9.765625
#         }
#     },
#     'gulprgb-DINO-B16-224': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 27.40885353088379,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 58.47856521606445
#         }
#     },
#     'gulprgb-DeiT3-B16-224': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 39.32291793823242,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 65.42467498779297
#         }
#     },
#     'gulprgb-Laion-B16-224': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 24.91486358642578,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 54.22175598144531
#         }
#     },
#     'gulprgb-EffFormer-s0': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 1.7578125,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 10.231369972229004
#         }
#     },
#     'gulprgb-EffV2-RW-S': {
#         'hmdb51': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 11.458333015441896,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 28.80608940124512
#         }
#     },
#     '101-gulprgb-MPNET': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 1.1292016506195068,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 6.039916038513184
#         }
#     },
#     '101-gulprgb-BERT': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 1.2867647409439087,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 6.039916038513184
#         }
#     },
#     '101-gulprgb-EffFormer-s0': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.7352941036224365,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 4.254201889038086
#         }
#     },
#     '101-gulprgb-EffV2-RW-S': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 11.055672645568848,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 28.90155982971191
#         }
#     },
#     '101-gulprgb-RNX50-32x4A1': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 19.747900009155277,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 42.17436981201172
#         }
#     },
#     '400-MPNET': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.25330850481987,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 1.251033902168274
#         }
#     },
#     '400-BERT': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.2688172161579132,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 1.269127368927002
#         }
#     },
#     '400-BART': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.2507237493991852,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 1.2639578580856323
#         }
#     },
#     '400-CLIP-B16-224HF-image': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.2558932900428772,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 1.2587882280349731
#         }
#     },
#     '400-CLIP-B16-224HF-text': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.25330850481987,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 1.2820513248443604
#         }
#     },
#     '400-AR-ViT-B16-224': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 34.63468551635742,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 61.313236236572266
#         }
#     },
#     '400-Laion-B16-224': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 44.57833862304688,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 71.65494537353516
#         }
#     },
#     '400-SViT-B16-224': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 25.79042625427246,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 51.82830047607422
#         }
#     },
#     '400-DINO-B16-224': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 33.212364196777344,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 59.91160202026367
#         }
#     },
#     '400-DeiT3-B16-224': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 40.27433013916016,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 67.59650421142578
#         }
#     },
#     '400-Flex-B-1200EP': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 43.73725128173828,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 70.72409057617188
#         }
#     },
#     '400-SIGLIP-P16-224': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 39.50733947753906,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 67.65336608886719
#         }
#     },
#     '400-EffV2-RW-S': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 1.0209884643554688,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 4.32692289352417
#         }
#     },
#     '400-EffFormer-s0': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.2688172161579132,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 1.2768816947937012
#         }
#     },
#     '400-RNX50-32x4A1': {
#         'kinetics': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 1.6490901708602903,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 6.366315364837647
#         }
#     },
#     'context-Whisper': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.5933501720428467,
#             'testing/ensemble_3/mIoU': 0.954404566437006
#         }
#     },
#     'context-CLIP-B16-224HF-text': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.5627897381782532,
#             'testing/ensemble_3/mIoU': 1.0316891595721245
#         }
#     },
#     'context-W2V2': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.5898061990737915,
#             'testing/ensemble_3/mIoU': 0.964104849845171
#         }
#     },
#     'context-MPNET': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.577487051486969,
#             'testing/ensemble_3/mIoU': 0.9465739130973816
#         }
#     },
#     'depth-v2-W2V2': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2390076667070388,
#             'testing/ensemble_3/mIoU': 4.294997081160545
#         }
#     },
#     'depth-v2-MPNET': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2418089359998703,
#             'testing/ensemble_3/mIoU': 5.430923402309418
#         }
#     },
#     'imagenetWhisper': {'mini': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.3415786325931549}},
#     'depth-v2-BART': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2399859577417373,
#             'testing/ensemble_3/mIoU': 4.983493313193321
#         }
#     },
#     'context-BART': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.5561875700950623,
#             'testing/ensemble_3/mIoU': 0.99612670019269
#         }
#     },
#     'depth-v2-BERT': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2407307028770446,
#             'testing/ensemble_3/mIoU': 5.392327904701233
#         }
#     },
#     'context-CLIP-B16-224HF-image': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.5952634811401367,
#             'testing/ensemble_3/mIoU': 0.973252858966589
#         }
#     },
#     'flowersWhisper': {'vgg': {'testing/ensemble_3/accuracy_top_1-epoch-mean': 0.5339769721031189}},
#     'depth-v2-CLIP-B16-224HF-image': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2407726943492889,
#             'testing/ensemble_3/mIoU': 5.019469186663628
#         }
#     },
#     'context-BERT': {
#         'pascal': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.543688178062439,
#             'testing/ensemble_3/mIoU': 0.9583874605596066
#         }
#     },
#     'depth-v2-Whisper': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2428339272737503,
#             'testing/ensemble_3/mIoU': 4.47222962975502
#         }
#     },
#     'depth-v2-CLIP-B16-224HF-text': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2470903396606445,
#             'testing/ensemble_3/mIoU': 4.762110114097595
#         }
#     },
#     'decathlon-spleen-BART': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9603369235992432}},
#     'decathlon-heart-Whisper': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.893710732460022}},
#     'decathlon-spleen-MPNET': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9444608688354492}},
#     'decathlon-pancreas-Whisper': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.732904851436615}},
#     'decathlon-pancreas-BERT': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.6779343485832214}},
#     'decathlon-heart-BERT': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.8971617221832275}},
#     'decathlon-pancreas-CLIP-B16-224HF-image': {
#         'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.7032662630081177}
#     },
#     'decathlon-hepatic-vessel-MPNET': {
#         'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9809442162513732}
#     },
#     'decathlon-colon-MPNET': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.5378132462501526}},
#     'decathlon-liver-BART': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.6591150164604187}},
#     'decathlon-lung-Whisper': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9998317360877992}},
#     'decathlon-hippocampus-CLIP-B16-224HF-text': {
#         'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.8980288505554199}
#     },
#     'decathlon-brain-tumour-BART': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': 0.9808578491210938}},
#     'decathlon-heart-SIGLIP-P16-224': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': None}},
#     '101-gulprgb-SIGLIP-P16-224': {
#         'ucf': {
#             'testing/ensemble_3/accuracy_top_1-epoch-mean': 69.92422485351562,
#             'testing/ensemble_3/accuracy_top_5-epoch-mean': 89.0868911743164
#         }
#     },
#     'decathlon-hippocampus-SIGLIP-P16-224': {'medical': {'testing/ensemble_3-/dice_loss-epoch-mean': None}},
#     'depth-v2-SIGLIP-P16-224': {
#         'nyu': {
#             'testing/ensemble_3/dice_loss-epoch-mean': 0.2375491261482238,
#             'testing/ensemble_3/mIoU': 7.785739004611969
#         }
#     }
# })

# %%
from dataclasses import dataclass
from rich import print

unique_dataset_names = set()
unique_models = set()

model_names = [
    "AR-ViT-B16-224",
    "BART",
    "BERT",
    "CLIP-B16-224",
    "CLIP-B16-224HF-image",
    "CLIP-B16-224HF-text",
    "ConvNextV2-Base",
    "DINO-B16-224",
    "DeiT3-B16-224",
    "EffFormer-s0",
    "EffV2-RW-S",
    "Flex-B-1200EP",
    "IJEPA-Huge-P14-224",
    "Laion-B16-224",
    "MPNET",
    "RNX50-32x4A1",
    "SIGLIP-P16-224",
    "SViT-B16-224",
    "W2V2",
    "Whisper",
]


@dataclass
class TargetMetrics:
    MIOU: str = "miou"
    ACC1: str = "acc1"
    ACC5: str = "acc5"


for idx, exp_name in enumerate(exp_names):
    exp_series = exp_name.split("-")[0]
    exp_seed = exp_name.split("-")[-1]
    exp_dataset_name = (
        dataset_names[idx]
        if dataset_names[idx] != "happy"
        else "whale-dolphin"
    )
    exp_dataset_name = (
        "clevr-math" if "clevr-math" in exp_name else "clevr"
        if dataset_names[idx] == "clevr"
        else dataset_names[idx]
    )
    exp_dataset_name = (
        "coco-10k" if "coco-10k" in exp_name else "coco-164k"
        if dataset_names[idx] == "coco"
        else dataset_names[idx]
    )
    model_name = exp_name.replace(exp_dataset_name, "")
    model_name = "-".join(model_name.split("-")[1:-1])
    model_name = model_name.replace("--", "").replace("classification-", "")
    model_name = model_name.replace("-fs-", "").replace("happy", "")
    model_name = model_name.replace("retionopathy", "")
    model_name = model_name[1:] if model_name[0] == "-" else model_name
    model_name = model_name[1:] if model_name[0] == "-" else model_name
    found = False
    for m in model_names:
        if m in model_name:
            model_name = m
            found = True
            break
    if not found:
        print(f"not found {model_name}")
    unique_dataset_names.add(exp_dataset_name)
    unique_models.add(model_name)
    # print(f"{exp_dataset_name} {model_name} {exp_seed}")

# print(unique_dataset_names)
# print(sorted(unique_models))
