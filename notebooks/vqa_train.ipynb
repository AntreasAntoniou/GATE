# %%
from datasets import load_dataset
import torch
import os

os.environ["HF_USERNAME"] = "Antreas"
os.environ["HF_TOKEN"] = "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"
os.environ["HF_CACHE_DIR"] = "/data/"

from gate.data.image.visual_question_answering.vqa_v2 import build_vqa_v2_dataset

dataset = test_data = load_dataset(
        path="HuggingFaceM4/VQAv2",
        split="validation",
        cache_dir=os.environ.get("HF_CACHE_DIR"),
    )
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 11
#       7 os.environ["HF_CACHE_DIR"] = "/data-fast1/dev/"
#       9 from gate.data.image.visual_question_answering.vqa_v2 import build_vqa_v2_dataset
# ---> 11 dataset = test_data = load_dataset(
#      12         path="HuggingFaceM4/VQAv2",
#      13         split="validation",
#      14         cache_dir=os.environ.get("HF_CACHE_DIR"),
#      15     )
#
# File /opt/conda/envs/main/lib/python3.10/site-packages/datasets/load.py:1797, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    1794 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    1796 # Download and prepare data
# ...

# %%
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 from gate.data.image.visual_question_answering.vqa_v2 import build_vqa_v2_dataset
# ----> 3 dataset = build_vqa_v2_dataset(set_name='train', data_dir=os.environ.get("HF_CACHE_DIR"))
#
# File /devcode/GATE-private/gate/data/image/visual_question_answering/vqa_v2.py:24, in build_vqa_v2_dataset(set_name, data_dir)
#      11 """
#      12 Build a VQA V2 dataset using the Hugging Face datasets library.
#      13
#    (...)
#      20     A dictionary containing the dataset split.
#      21 """
#      22 rng = np.random.RandomState(42)
# ---> 24 train_val_data = load_dataset(
#      25     path="HuggingFaceM4/VQAv2",
#      26     split="train",
#      27     cache_dir=data_dir,
#      28 )
#      30 test_data = load_dataset(
#      31     path="HuggingFaceM4/VQAv2",
#      32     split="validation",
# ...
