# %%
import os
import torch
import datasets
import numpy as np
import matplotlib.pyplot as plt
import multiprocessing as mp

# %%
from gate.data.medical.segmentation.automated_cardiac_diagnosis import build_gate_dataset

data = build_gate_dataset(data_dir=os.environ.get("PYTEST_DIR"), image_size=64, target_image_size=64)
# Out:
# Found cached dataset parquet (/home/evolvingfungus/.cache/huggingface/datasets/GATE-engine___parquet/GATE-engine--automated_cardiac_diagnosis_competition.ACDC-b3cd992997e71bd3/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# Found cached dataset parquet (/home/evolvingfungus/.cache/huggingface/datasets/GATE-engine___parquet/GATE-engine--automated_cardiac_diagnosis_competition.ACDC-b3cd992997e71bd3/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# Found cached dataset parquet (/home/evolvingfungus/.cache/huggingface/datasets/GATE-engine___parquet/GATE-engine--automated_cardiac_diagnosis_competition.ACDC-b3cd992997e71bd3/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# Found cached dataset parquet (/home/evolvingfungus/.cache/huggingface/datasets/GATE-engine___parquet/GATE-engine--automated_cardiac_diagnosis_competition.ACDC-b3cd992997e71bd3/0.0.0/14a00e99c0d15a23649d0db8944380ac81082d4b021f398733dd84f3a6c569a7)
# ...

# %%
from torch.utils.data import DataLoader

dataloader = DataLoader(data['train'], batch_size=1, shuffle=True, num_workers=1)

# %%
from tqdm.auto import tqdm

for batch in tqdm(dataloader):
    break
# Out:
#   0%|          | 0/90000000 [00:05<?, ?it/s]
# /home/evolvingfungus/miniconda/envs/gate/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# ...

# %%
print(f"shape: {batch['four_d_img'].shape}, dtype: {batch['four_d_img'].dtype}")
print(f"shape: {batch['frame_data'].shape}, dtype: {batch['frame_data'].dtype}")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 print(f"shape: {batch['four_d_img'].shape}, dtype: {batch['four_d_img'].dtype}")             │
# │   2 print(f"shape: {batch['frame_data'].shape}, dtype: {batch['frame_data'].dtype}")             │
# │   3                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: 'list' object has no attribute 'shape'
