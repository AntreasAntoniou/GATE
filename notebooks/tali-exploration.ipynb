# %%
import os


os.environ["WANDB_API_KEY"] = "821661c6ee1657a2717093701ab76574ae1a9be0"
os.environ["WANDB_ENTITY"] = "machinelearningbrewery"
os.environ["WANDB_PROJECT"] = "gate-exp-0-8-6"

os.environ["KAGGLE_USERNAME"] = "antreasantoniou"
os.environ["KAGGLE_KEY"] = "d14aab63e71334cfa118bd5251bf85da"

os.environ["DATASET_DIR"] = "/data0/"
os.environ["PROJECT_DIR"] = "$PYTEST_DIR"

os.environ["EXPERIMENT_NAME"] = "gate-dev-0-8-6"
os.environ["HF_USERNAME"] = "Antreas"
os.environ["HF_TOKEN"] = "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"
os.environ["HF_CACHE_DIR"] = "$PYTEST_DIR"

os.environ["TOKENIZERS_PARALLELISM"] = "False"

os.environ["CODE_DIR"] = "/devcode/GATE-private/"
os.environ["EXPERIMENT_NAME_PREFIX"] = "gate-exp-0"
os.environ["EXPERIMENTS_ROOT_DIR"] = "$PROJECT_DIR"
os.environ["EXPERIMENTS_DIR"] = "$PROJECT_DIR"
os.environ["EXPERIMENT_DIR"] = "$PROJECT_DIR"
os.environ["MODEL_DIR"] = "$PROJECT_DIR"

os.environ["PYTEST_DIR"] = "$DATASET_DIR"
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:56                                                                                   │
# │                                                                                                  │
# │   53 dataset_dict = datasets.load_dataset(                                                       │
# │   54 │   path="Antreas/TALI",                                                                    │
# │   55 │   keep_in_memory=False,                                                                   │
# │ ❱ 56 │   cache_dir=os.environ["HF_CACHE_DIR"],                                                   │
# │   57 )                                                                                           │
# │   58 dataset_dict = dataset_dict.with_transform(transform)                                       │
# ...

# %%
import os

from tali.data.data import ModalityTypes

os.environ["HYDRA_FULL_ERROR"] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

import pathlib
import random

import datasets
from rich import print
from rich.traceback import install

install()


import gradio as gr
import torchaudio
import torchvision

from tali.utils import get_logger

logger = logging.getLogger(__name__)

from tali.data.data_plus import TALIBaseTransform, TALIBaseTransformConfig

data_root = "/data/"
transform = TALIBaseTransform(
    config=TALIBaseTransformConfig(
        root_filepath=data_root,
        modality_list=[
            ModalityTypes.wit_image.value,
            ModalityTypes.wit_caption.value,
            ModalityTypes.wit_title.value,
            ModalityTypes.wit_main_body.value,
            ModalityTypes.youtube_image.value,
            ModalityTypes.youtube_video.value,
            ModalityTypes.youtube_subtitles.value,
            ModalityTypes.youtube_audio.value,
            ModalityTypes.youtube_description.value,
        ],
        rng_seed=42,
        top_k_tali=10,
        image_size=224,
        num_video_frames=25 * 25,
        num_audio_frames=25 * 16000,
        clip_duration_in_seconds=25.0,
        deterministic_sampling=True,
    )
)
dataset_dict = datasets.load_dataset(
    path="Antreas/TALI",
    keep_in_memory=False,
    cache_dir=os.environ["HF_CACHE_DIR"],
)
dataset_dict = dataset_dict.with_transform(transform)
