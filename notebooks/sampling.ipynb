# %%
from collections import defaultdict
import os
from rich import print
from gate.data.image.visual_question_answering.ok_vqa import (
    build_ok_vqa_dataset,
)
from gate.data.image.visual_question_answering.vqa_v2 import (
    build_vqa_v2_dataset,
)

import tqdm.auto as tqdm


vqa_train_vqa = build_vqa_v2_dataset(
    "train", data_dir=os.environ.get("PYTEST_DIR")
)
answer_type_dict = defaultdict(int)
answer_content_dict = defaultdict(int)
with tqdm.tqdm(total=len(vqa_train_vqa)) as pbar:
    for idx, item in enumerate(vqa_train_vqa):
        answer_type_dict[item["answer_type"]] += 1
        if item["answer_type"] == "number":
            for answer in item["answers"]:
                answer_content_dict[answer["answer"]] += 1
        pbar.update(1)
        pbar.set_description(f"Answer type dict: {answer_content_dict}")
# Out:
# Found cached dataset vq_av2 (/home/evolvingfungus/.cache/huggingface/datasets/HuggingFaceM4___vq_av2/default/1.0.0/e4d008385143be7a6bd81e99483e671d5096942bcb987542217121a5ac2cb420)
# Found cached dataset vq_av2 (/home/evolvingfungus/.cache/huggingface/datasets/HuggingFaceM4___vq_av2/default/1.0.0/e4d008385143be7a6bd81e99483e671d5096942bcb987542217121a5ac2cb420)
#   0%|          | 0/399381 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 20
#      18 answer_content_dict = defaultdict(int)
#      19 with tqdm.tqdm(total=len(vqa_train_vqa)) as pbar:
# ---> 20     for idx, item in enumerate(vqa_train_vqa):
#      21         answer_type_dict[item["answer_type"]] += 1
#      22         if item["answer_type"] == "number":
#
# ...

# %%
ok_train_set = build_ok_vqa_dataset(
    "train", data_dir=os.environ.get("PYTEST_DIR")
)

for idx, item in enumerate(ok_train_set):
    print(item)
    if idx == 20:
        break
# Out:
# Found cached dataset parquet (/home/evolvingfungus/.cache/huggingface/datasets/Multimodal-Fatima___parquet/Multimodal-Fatima--OK-VQA_train-c49be14e3379d8e4/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]
# Found cached dataset parquet (/home/evolvingfungus/.cache/huggingface/datasets/Multimodal-Fatima___parquet/Multimodal-Fatima--OK-VQA_test-b8b511529aaa684c/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]
# {
#     'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x425 at 0x7F07894C3BE0>,
#     'question_type': 'one',
#     'confidence': 4,
#     'answers': [
#         'double decker',
#         'double decker',
#         'double decker',
#         'double decker',
#         'double decker',
#         'double decker',
#         'double decker',
#         'double decker',
#         'tour',
#         'tour'
#     ],
# ...
